# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader  as web  #this is new n and used to collect data from online

# %%
df=pd.read_csv('D:\\python\\Titanic_ML\\dollar vs Rs\\EXINUS.csv')
df=df.dropna(how='any')

# %%
df.head()
# Out:
#          DATE  EXINUS
# 0  1973-01-01  8.0041
# 1  1973-02-01  7.7538
# 2  1973-03-01  7.5465
# 3  1973-04-01  7.5462
# 4  1973-05-01  7.4927

# %%
plt.figure(figsize=(15,8))
df['EXINUS'].plot(grid=True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 2 columns):
# DATE      549 non-null object
# EXINUS    549 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 8.7+ KB
